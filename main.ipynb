# %%
# !pip install langchain openai google-generativeai huggingface_hub
# !pip install langchain_community langchain_core
# Out:
# ...
#      -------------------------------------- 755.1/755.1 kB 9.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 155.4/155.4 kB 9.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 515.4/515.4 kB 31.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 208.8/208.8 kB 13.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 216.1/216.1 kB ? eta 0:00:00
# ...
#      -------------------------------------- 160.8/160.8 kB 4.9 MB/s eta 0:00:00
# ...
#      --------------------------------------- 13.7/13.7 MB 10.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 435.3/435.3 kB 13.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.3/1.3 MB 10.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 434.9/434.9 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 50.2/50.2 kB ? eta 0:00:00
# ...
#      -------------------------------------- 199.1/199.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !pip install
